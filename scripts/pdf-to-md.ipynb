# %%
pip install torch torchvision --index-url https://download.pytorch.org/whl/cu132
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu132
# Requirement already satisfied: torch in c:\users\quinn\anaconda3\lib\site-packages (2.12.0)
# Collecting torchvision
#   Downloading https://download-r2.pytorch.org/whl/cu132/torchvision-0.27.0%2Bcu132-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in c:\users\quinn\anaconda3\lib\site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\quinn\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\quinn\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\quinn\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\quinn\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\quinn\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\quinn\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in c:\users\quinn\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\quinn\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\quinn\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\quinn\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Downloading https://download-r2.pytorch.org/whl/cu132/torchvision-0.27.0%2Bcu132-cp312-cp312-win_amd64.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 9.1/9.1 MB 79.9 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.27.0+cu132
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["TORCH_DEVICE"] = "cuda"

# %%
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.output import text_from_rendered

# %%
converter = PdfConverter(
    artifact_dict=create_model_dict(),
)
rendered = converter("../.raw/Joshi et al. - 2015 - When Can Women Close the Gap A Meta-Analytic Test of Sex Differences in Performance and Rewards.pdf")
text, _, metadata = text_from_rendered(rendered)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 converter = PdfConverter(
# ----> 2     artifact_dict=create_model_dict(),
#       3 )
#       4 rendered = converter("../.raw/Joshi et al. - 2015 - When Can Women Close the Gap A Meta-Analytic Test of Sex Differences in Performance and Rewards.pdf")
#       5 text, _, metadata = text_from_rendered(rendered)
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\marker\models.py:20, in create_model_dict(device, dtype, attention_implementation)
#      16 def create_model_dict(
#      17     device=None, dtype=None, attention_implementation: str | None = None
#      18 ) -> dict:
#      19     return {
# ---> 20         "layout_model": LayoutPredictor(FoundationPredictor(checkpoint=surya_settings.LAYOUT_MODEL_CHECKPOINT, attention_implementation=attention_implementation, device=device, dtype=dtype)),
#      21         "recognition_model": RecognitionPredictor(FoundationPredictor(checkpoint=surya_settings.RECOGNITION_MODEL_CHECKPOINT, attention_implementation=attention_implementation, device=device, dtype=dtype)),
#      22         "table_rec_model": TableRecPredictor(device=device, dtype=dtype),
#      23         "detection_model": DetectionPredictor(device=device, dtype=dtype),
#      24         "ocr_error_model": OCRErrorPredictor(device=device, dtype=dtype),
#      25     }
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\surya\foundation\__init__.py:113, in FoundationPredictor.__init__(self, checkpoint, device, dtype, attention_implementation)
#     106 def __init__(
#     107     self,
#     108     checkpoint=None,
#    (...)
#     111     attention_implementation: Optional[str] = None,
#     112 ):
# --> 113     super().__init__(checkpoint, device, dtype, attention_implementation)
#     114     self.prompt_queue = deque()
#     115     self.batch_prompt_mapping = None
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\surya\common\predictor.py:37, in BasePredictor.__init__(self, checkpoint, device, dtype, attention_implementation)
#      34 self.processor = None
#      35 loader = self.model_loader_cls(checkpoint)
# ---> 37 self.model = loader.model(device, dtype, attention_implementation)
#      38 self.processor = loader.processor()
#      40 self._disable_tqdm = settings.DISABLE_TQDM
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\surya\foundation\loader.py:71, in FoundationModelLoader.model(self, device, dtype, attention_implementation)
#      66 config.vision_encoder._attn_implementation_autoset = True
#      67 config.decoder._attn_implementation_autoset = True
#      69 model = model_cls.from_pretrained(
#      70     self.checkpoint, dtype=dtype, config=config, ignore_mismatched_sizes=True
# ---> 71 ).to(device)
#      72 model = model.eval()
#      74 if settings.COMPILE_ALL or settings.COMPILE_FOUNDATION:
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\transformers\modeling_utils.py:4343, in PreTrainedModel.to(self, *args, **kwargs)
#    4338     if dtype_present_in_args:
#    4339         raise ValueError(
#    4340             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    4341             " `dtype` by passing the correct `dtype` argument."
#    4342         )
# -> 4343 return super().to(*args, **kwargs)
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1383, in Module.to(self, *args, **kwargs)
#    1380         else:
#    1381             raise
# -> 1383 return self._apply(convert)
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\torch\nn\modules\module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 from torch._subclasses.fake_tensor import FakeTensor
#     937 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\torch\nn\modules\module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 from torch._subclasses.fake_tensor import FakeTensor
#     937 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\torch\nn\modules\module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 from torch._subclasses.fake_tensor import FakeTensor
#     937 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\torch\nn\modules\module.py:964, in Module._apply(self, fn, recurse)
#     960 # Tensors stored in modules are graph leaves, and we don't want to
#     961 # track autograd history of `param_applied`, so we have to use
#     962 # `with torch.no_grad():`
#     963 with torch.no_grad():
# --> 964     param_applied = fn(param)
#     965 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     967 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1369, in Module.to.<locals>.convert(t)
#    1362     if convert_to_format is not None and t.dim() in (4, 5):
#    1363         return t.to(
#    1364             device,
#    1365             dtype if t.is_floating_point() or t.is_complex() else None,
#    1366             non_blocking,
#    1367             memory_format=convert_to_format,
#    1368         )
# -> 1369     return t.to(
#    1370         device,
#    1371         dtype if t.is_floating_point() or t.is_complex() else None,
#    1372         non_blocking,
#    1373     )
#    1374 except NotImplementedError as e:
#    1375     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File c:\Users\quinn\anaconda3\Lib\site-packages\torch\cuda\__init__.py:484, in _lazy_init()
#     479     raise RuntimeError(
#     480         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     481         "multiprocessing, you must use the 'spawn' start method"
#     482     )
#     483 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 484     raise AssertionError("Torch not compiled with CUDA enabled")
#     485 if _cudart is None:
#     486     raise AssertionError(
#     487         "libcudart functions unavailable. It looks like you have a broken build?"
#     488     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
text
# Out:
# {'_page_0_Figure_0.jpeg': <PIL.Image.Image image mode=RGB size=895x102>,
#  '_page_1_Picture_3.jpeg': <PIL.Image.Image image mode=RGB size=200x81>,
#  '_page_11_Figure_2.jpeg': <PIL.Image.Image image mode=RGB size=1011x587>,
#  '_page_13_Figure_5.jpeg': <PIL.Image.Image image mode=RGB size=673x678>}

# %%
with open("Joshi et al. - 2015 - When Can Women Close the Gap A Meta-Analytic Test of Sex Differences in Performance and Rewards.pdf", "x", encoding="utf-8") as file:
        file.write(text)
